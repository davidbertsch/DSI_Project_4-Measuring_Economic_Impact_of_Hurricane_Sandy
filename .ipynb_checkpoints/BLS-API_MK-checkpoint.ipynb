# %% [markdown]
# ### Gathering wage data from bls.gov API

# %% [markdown]
# The registration keys from bls.gov have been deleted from the notebook. Information on how to get a registration key can be found here: https://data.bls.gov/registrationEngine/

# %%
keys = []

# %%
import requests
import json
import pandas as pd
import numpy as np

# %% [markdown]
# The following code was built off of the API scraping script that the Boston group from the last DSI cohort wrote. Their project github is linked here: https://github.com/EricPmWong/NewLightTechQ11

# %% [markdown]
# The function below scrapes the website of the Bureau of Labor Statistics. Information about how to access that API can be found here: https://www.bls.gov/developers/home.htm

# %% [markdown]
# This particular series that were scraped for this project are taken from the Quarterly Census of Labor and Wages. Information on how the series ID numbers are formatted can be found here: https://www.bls.gov/help/hlpforma.htm

# %%
def bls_pull(registration_key, area_code, start_year, end_year):
    
    



    industries = {'11': 'natural_resources_mining',
                  '12': 'construction',
                  '13': 'manufacturing',
                  '21': 'trade_transportation_utilities',
                  '22': 'information',
                  '23': 'financial_activities',
                  '24': 'professional_business_services',
                  '25': 'education_health_services',
                  '26': 'leisure_hospitality',
                  '27': 'other_services',
                  '28': 'public_administration',
                  '29': 'unclassified'}

    data_names = {'1': 'all_employees',
                  '4': 'avg_weekly_pay'}




    json_dicts = {}

    for i_code, i_name in industries.items():

        for d_code, d_name in data_names.items():

            headers = {'Content-type': 'application/json'}
            data = json.dumps({"seriesid": ['ENU'+ area_code + d_code + '0510' + i_code],'registrationkey': registration_key, 
                               "startyear": start_year, "endyear": end_year})
            p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
            json_data = json.loads(p.text)

            json_dicts[i_name + '_' + d_name] = json_data['Results']['series'][0]['data']

    bad_keys = []
    for i in json_dicts:
        if len(json_dicts[i]) == 0:
            bad_keys.append(i) 

    for i in bad_keys:
        del json_dicts[i]




    df_dicts = {}

    for i in json_dicts:
        df_dicts[i] = pd.DataFrame(json_dicts[i])

    for i in df_dicts:

        if 'avg_weekly_pay' in i:
            df_dicts[i][i] = df_dicts[i]['value']
            df_dicts[i]['date'] = df_dicts[i].apply(lambda x: x['year'] + x['period'][1:], axis=1)
            df_dicts[i] = pd.concat([df_dicts[i]['date'], df_dicts[i][i]], axis=1)

        elif 'all_employees' in i:
            df_dicts[i][i] = df_dicts[i]['value']
            df_dicts[i]['date'] = df_dicts[i].apply(lambda x: x['year'] + x['period'][1:], axis=1)
            df_dicts[i] = pd.concat([df_dicts[i]['date'], df_dicts[i][i]], axis=1)

        cols = [j for j in df_dicts[i] if j != 'date']
        df_dicts[i][cols] = df_dicts[i][cols].apply(pd.to_numeric, errors='coerce')

    for df_key in df_dicts:

        wp_mask = df_key.split('all')[0] + 'avg_weekly_pay'

        if 'all_employees' in df_key:

            df_dicts[df_key][wp_mask] = 0

            for index, period in df_dicts[df_key]['date'].iteritems():
                if period[4:] in ['01', '02', '03']:
                    df_dicts[df_key].loc[index, wp_mask] = 4 * df_dicts[wp_mask][df_dicts[wp_mask]['date']==(period[:4]+'01')][wp_mask].iloc[0]
                if period[4:] in ['04', '05', '06']:
                    df_dicts[df_key].loc[index, wp_mask] = 4 * df_dicts[wp_mask][df_dicts[wp_mask]['date']==(period[:4]+'02')][wp_mask].iloc[0]
                if period[4:] in ['07', '08', '09']:
                    df_dicts[df_key].loc[index, wp_mask] = 4 * df_dicts[wp_mask][df_dicts[wp_mask]['date']==(period[:4]+'03')][wp_mask].iloc[0]
                if period[4:] in ['10', '11', '12']:
                    df_dicts[df_key].loc[index, wp_mask] = 4 * df_dicts[wp_mask][df_dicts[wp_mask]['date']==(period[:4]+'04')][wp_mask].iloc[0]

            df_dicts[df_key].rename(columns={wp_mask: df_key.split('all')[0] + 'avg_monthly_pay'}, inplace=True)
            df_dicts[df_key][df_key.split('all')[0] + 'aggr_value'] = df_dicts[df_key][df_key] * df_dicts[df_key][df_key.split('all')[0] + 'avg_monthly_pay']

    merged_df = pd.DataFrame(columns=['date'])

    for df_key in df_dicts:
        if 'all_employees' in df_key:
            merged_df = pd.merge(merged_df, df_dicts[df_key], how = 'outer', on ='date')

    temp_merge = merged_df.drop('date', axis=1)
    temp_cols = [i for i in temp_merge.columns if 'aggr_val' in i]
    merged_df['total_industries_aggr_value'] = temp_merge[temp_cols].apply(lambda x: sum(x), axis=1)
    
    #Reverses Dates:
    merged_df = merged_df[::-1]
    #Formates Dates year and month split
    merged_df['date'] = [x[:4]+'-'+x[4:8] for x in merged_df['date']]
    
    return pd.DataFrame(merged_df)

# %% [markdown]
# ### Atlantic City, NJ

# %%
city = "AtlanticCity"
start = "2010"
end = "2015"
code= "C1210"

# %%
acnj = bls_pull(registration_key=keys[0], start_year=start, end_year=end, area_code=code)

# %%
acnj.head().T
# Out:
#                                                          71           70  \
# date                                                2010-01      2010-02
# natural_resources_mining_all_employees                  402          346
# natural_resources_mining_avg_monthly_pay               2324         2324
# natural_resources_mining_aggr_value                  934248       804104
# construction_all_employees                             4124         3829
# construction_avg_monthly_pay                           4172         4172
# construction_aggr_value                            17205328     15974588
# manufacturing_all_employees                            2066         2023
# manufacturing_avg_monthly_pay                          3568         3568
# manufacturing_aggr_value                            7371488      7218064
# trade_transportation_utilities_all_employees          19835        19359
# trade_transportation_utilities_avg_monthly_pay         2384         2384
# trade_transportation_utilities_aggr_value          47286640     46151856
# information_all_employees                               935          918
# information_avg_monthly_pay                            3300         3300
# information_aggr_value                              3085500      3029400
# financial_activities_all_employees                     3884         3902
# financial_activities_avg_monthly_pay                   3808         3808
# financial_activities_aggr_value                    14790272     14858816
# professional_business_services_all_employees           8806         8793
# professional_business_services_avg_monthly_pay         3760         3760
# professional_business_services_aggr_value          33110560     33061680
# education_health_services_all_employees               17145        17091
# education_health_services_avg_monthly_pay              3300         3300
# education_health_services_aggr_value               56578500     56400300
# leisure_hospitality_all_employees                     45393        45533
# leisure_hospitality_avg_monthly_pay                    2256         2256
# leisure_hospitality_aggr_value                    102406608    102722448
# other_services_all_employees                           3534         3487
# other_services_avg_monthly_pay                         1968         1968
# other_services_aggr_value                           6954912      6862416
# unclassified_all_employees                               13           15
# unclassified_avg_monthly_pay                           1176         1176
# unclassified_aggr_value                               15288        17640
# total_industries_aggr_value                     2.89739e+08  2.87101e+08
#
#                                                          69          68  \
# date                                                2010-03     2010-04
# natural_resources_mining_all_employees                  455         607
# natural_resources_mining_avg_monthly_pay               2324        1480
# natural_resources_mining_aggr_value                 1057420      898360
# construction_all_employees                             4133        4369
# construction_avg_monthly_pay                           4172        4320
# construction_aggr_value                            17242876    18874080
# manufacturing_all_employees                            2095        2160
# manufacturing_avg_monthly_pay                          3568        3756
# manufacturing_aggr_value                            7474960     8112960
# trade_transportation_utilities_all_employees          19554       19885
# trade_transportation_utilities_avg_monthly_pay         2384        2400
# trade_transportation_utilities_aggr_value          46616736    47724000
# information_all_employees                               886         885
# information_avg_monthly_pay                            3300        3372
# information_aggr_value                              2923800     2984220
# financial_activities_all_employees                     3920        3943
# financial_activities_avg_monthly_pay                   3808        3624
# financial_activities_aggr_value                    14927360    14289432
# professional_business_services_all_employees           9167        9395
# professional_business_services_avg_monthly_pay         3760        3768
# professional_business_services_aggr_value          34467920    35400360
# education_health_services_all_employees               17176       17284
# education_health_services_avg_monthly_pay              3300        3580
# education_health_services_aggr_value               56680800    61876720
# leisure_hospitality_all_employees                     46326       47364
# leisure_hospitality_avg_monthly_pay                    2256        2268
# leisure_hospitality_aggr_value                    104511456   107421552
# other_services_all_employees                           3524        3573
# other_services_avg_monthly_pay                         1968        2064
# other_services_aggr_value                           6935232     7374672
# unclassified_all_employees                               16          11
# unclassified_avg_monthly_pay                           1176        1244
# unclassified_aggr_value                               18816       13684
# total_industries_aggr_value                     2.92857e+08  3.0497e+08
#
#                                                          67
# date                                                2010-05
# natural_resources_mining_all_employees                  731
# natural_resources_mining_avg_monthly_pay               1480
# natural_resources_mining_aggr_value                 1081880
# construction_all_employees                             4591
# construction_avg_monthly_pay                           4320
# construction_aggr_value                            19833120
# manufacturing_all_employees                            2227
# manufacturing_avg_monthly_pay                          3756
# manufacturing_aggr_value                            8364612
# trade_transportation_utilities_all_employees          20324
# trade_transportation_utilities_avg_monthly_pay         2400
# trade_transportation_utilities_aggr_value          48777600
# information_all_employees                               871
# information_avg_monthly_pay                            3372
# information_aggr_value                              2937012
# financial_activities_all_employees                     4002
# financial_activities_avg_monthly_pay                   3624
# financial_activities_aggr_value                    14503248
# professional_business_services_all_employees           9276
# professional_business_services_avg_monthly_pay         3768
# professional_business_services_aggr_value          34951968
# education_health_services_all_employees               17407
# education_health_services_avg_monthly_pay              3580
# education_health_services_aggr_value               62317060
# leisure_hospitality_all_employees                     49096
# leisure_hospitality_avg_monthly_pay                    2268
# leisure_hospitality_aggr_value                    111349728
# other_services_all_employees                           3683
# other_services_avg_monthly_pay                         2064
# other_services_aggr_value                           7601712
# unclassified_all_employees                               16
# unclassified_avg_monthly_pay                           1244
# unclassified_aggr_value                               19904
# total_industries_aggr_value                     3.11738e+08

# %%
acnj.to_csv("./bls-api-data/" +str(city)+str(start)+'-'+str(end)+".csv")

# %% [markdown]
# ### Bridgeport, CT

# %%
city = "Bridgeport"
start = "2010"
end = "2015"
code= "C1486"

# %%
bpct = bls_pull(registration_key=keys[0], start_year=start, end_year=end, area_code=code)

# %%
bpct.head().T
# Out:
#                                                         71          70  \
# date                                               2010-01     2010-02
# natural_resources_mining_all_employees                 329         326
# natural_resources_mining_avg_monthly_pay              3376        3376
# natural_resources_mining_aggr_value                1110704     1100576
# construction_all_employees                            9513        9322
# construction_avg_monthly_pay                          4244        4244
# construction_aggr_value                           40373172    39562568
# manufacturing_all_employees                          37362       37263
# manufacturing_avg_monthly_pay                         7416        7416
# manufacturing_aggr_value                         277076592   276342408
# trade_transportation_utilities_all_employees         70061       68577
# trade_transportation_utilities_avg_monthly_pay        4480        4480
# trade_transportation_utilities_aggr_value        313873280   307224960
# information_all_employees                            10309       10262
# information_avg_monthly_pay                           6640        6640
# information_aggr_value                            68451760    68139680
# financial_activities_all_employees                   42094       42080
# financial_activities_avg_monthly_pay                 24380       24380
# financial_activities_aggr_value                 1026251720  1025910400
# professional_business_services_all_employees         58367       58571
# professional_business_services_avg_monthly_pay        8828        8828
# professional_business_services_aggr_value        515263876   517064788
# education_health_services_all_employees              65629       65781
# education_health_services_avg_monthly_pay             3524        3524
# education_health_services_aggr_value             231276596   231812244
# leisure_hospitality_all_employees                    30024       29913
# leisure_hospitality_avg_monthly_pay                   1828        1828
# leisure_hospitality_aggr_value                    54883872    54680964
# other_services_all_employees                         15908       15744
# other_services_avg_monthly_pay                        2324        2324
# other_services_aggr_value                         36970192    36589056
# unclassified_all_employees                              42          45
# unclassified_avg_monthly_pay                          3796        3796
# unclassified_aggr_value                             159432      170820
# total_industries_aggr_value                     2565691196  2558598464
#
#                                                         69          68  \
# date                                               2010-03     2010-04
# natural_resources_mining_all_employees                 342         359
# natural_resources_mining_avg_monthly_pay              3376        3432
# natural_resources_mining_aggr_value                1154592     1232088
# construction_all_employees                            9523       10830
# construction_avg_monthly_pay                          4244        4232
# construction_aggr_value                           40415612    45832560
# manufacturing_all_employees                          37309       37280
# manufacturing_avg_monthly_pay                         7416        6216
# manufacturing_aggr_value                         276683544   231732480
# trade_transportation_utilities_all_employees         68785       69082
# trade_transportation_utilities_avg_monthly_pay        4480        3916
# trade_transportation_utilities_aggr_value        308156800   270525112
# information_all_employees                            10300       10412
# information_avg_monthly_pay                           6640        5868
# information_aggr_value                            68392000    61097616
# financial_activities_all_employees                   42160       42214
# financial_activities_avg_monthly_pay                 24380       14540
# financial_activities_aggr_value                 1027860800   613791560
# professional_business_services_all_employees         59430       62076
# professional_business_services_avg_monthly_pay        8828        6620
# professional_business_services_aggr_value        524648040   410943120
# education_health_services_all_employees              66379       66528
# education_health_services_avg_monthly_pay             3524        3784
# education_health_services_aggr_value             233919596   251741952
# leisure_hospitality_all_employees                    30615       32345
# leisure_hospitality_avg_monthly_pay                   1828        1844
# leisure_hospitality_aggr_value                    55964220    59644180
# other_services_all_employees                         15926       16237
# other_services_avg_monthly_pay                        2324        2428
# other_services_aggr_value                         37012024    39423436
# unclassified_all_employees                              49          31
# unclassified_avg_monthly_pay                          3796        5068
# unclassified_aggr_value                             186004      157108
# total_industries_aggr_value                     2574393232  1986121212
#
#                                                         67
# date                                               2010-05
# natural_resources_mining_all_employees                 375
# natural_resources_mining_avg_monthly_pay              3432
# natural_resources_mining_aggr_value                1287000
# construction_all_employees                           11166
# construction_avg_monthly_pay                          4232
# construction_aggr_value                           47254512
# manufacturing_all_employees                          37468
# manufacturing_avg_monthly_pay                         6216
# manufacturing_aggr_value                         232901088
# trade_transportation_utilities_all_employees         70805
# trade_transportation_utilities_avg_monthly_pay        3916
# trade_transportation_utilities_aggr_value        277272380
# information_all_employees                            10481
# information_avg_monthly_pay                           5868
# information_aggr_value                            61502508
# financial_activities_all_employees                   42401
# financial_activities_avg_monthly_pay                 14540
# financial_activities_aggr_value                  616510540
# professional_business_services_all_employees         62383
# professional_business_services_avg_monthly_pay        6620
# professional_business_services_aggr_value        412975460
# education_health_services_all_employees              66915
# education_health_services_avg_monthly_pay             3784
# education_health_services_aggr_value             253206360
# leisure_hospitality_all_employees                    34227
# leisure_hospitality_avg_monthly_pay                   1844
# leisure_hospitality_aggr_value                    63114588
# other_services_all_employees                         16431
# other_services_avg_monthly_pay                        2428
# other_services_aggr_value                         39894468
# unclassified_all_employees                              32
# unclassified_avg_monthly_pay                          5068
# unclassified_aggr_value                             162176
# total_industries_aggr_value                     2006081080

# %%
bpct.to_csv("./bls-api-data/" +str(city)+str(start)+'-'+str(end)+".csv")

# %% [markdown]
# ### New Haven, CT

# %%
city = "NewHaven"
start = "2010"
end = "2015"
code= "C3530"

# %%
nhct = bls_pull(registration_key=keys[0], start_year=start, end_year=end, area_code=code)

# %%
nhct.head().T
# Out:
#                                                         71          70  \
# date                                               2010-01     2010-02
# natural_resources_mining_all_employees                 692         669
# natural_resources_mining_avg_monthly_pay              2548        2548
# natural_resources_mining_aggr_value                1763216     1704612
# construction_all_employees                           10373       10122
# construction_avg_monthly_pay                          4352        4352
# construction_aggr_value                           45143296    44050944
# manufacturing_all_employees                          33348       33227
# manufacturing_avg_monthly_pay                         4820        4820
# manufacturing_aggr_value                         160737360   160154140
# trade_transportation_utilities_all_employees         63001       61772
# trade_transportation_utilities_avg_monthly_pay        2804        2804
# trade_transportation_utilities_aggr_value        176654804   173208688
# information_all_employees                             6539        6472
# information_avg_monthly_pay                           5336        5336
# information_aggr_value                            34892104    34534592
# financial_activities_all_employees                   15686       15664
# financial_activities_avg_monthly_pay                  5260        5260
# financial_activities_aggr_value                   82508360    82392640
# professional_business_services_all_employees         33743       34619
# professional_business_services_avg_monthly_pay        4832        4832
# professional_business_services_aggr_value        163046176   167279008
# education_health_services_all_employees              87658       88547
# education_health_services_avg_monthly_pay             3648        3648
# education_health_services_aggr_value             319776384   323019456
# leisure_hospitality_all_employees                    25028       25523
# leisure_hospitality_avg_monthly_pay                   1260        1260
# leisure_hospitality_aggr_value                    31535280    32158980
# other_services_all_employees                         11898       11968
# other_services_avg_monthly_pay                        2016        2016
# other_services_aggr_value                         23986368    24127488
# unclassified_all_employees                              12           9
# unclassified_avg_monthly_pay                          1732        1732
# unclassified_aggr_value                              20784       15588
# total_industries_aggr_value                     1040064132  1042646136
#
#                                                         69          68  \
# date                                               2010-03     2010-04
# natural_resources_mining_all_employees                 786        1060
# natural_resources_mining_avg_monthly_pay              2548        2724
# natural_resources_mining_aggr_value                2002728     2887440
# construction_all_employees                           10447       11465
# construction_avg_monthly_pay                          4352        4356
# construction_aggr_value                           45465344    49941540
# manufacturing_all_employees                          33377       33414
# manufacturing_avg_monthly_pay                         4820        4564
# manufacturing_aggr_value                         160877140   152501496
# trade_transportation_utilities_all_employees         62068       61884
# trade_transportation_utilities_avg_monthly_pay        2804        2960
# trade_transportation_utilities_aggr_value        174038672   183176640
# information_all_employees                             6439        6373
# information_avg_monthly_pay                           5336        4872
# information_aggr_value                            34358504    31049256
# financial_activities_all_employees                   15720       15679
# financial_activities_avg_monthly_pay                  5260        4620
# financial_activities_aggr_value                   82687200    72436980
# professional_business_services_all_employees         34455       35405
# professional_business_services_avg_monthly_pay        4832        4360
# professional_business_services_aggr_value        166486560   154365800
# education_health_services_all_employees              88463       89253
# education_health_services_avg_monthly_pay             3648        3912
# education_health_services_aggr_value             322713024   349157736
# leisure_hospitality_all_employees                    25868       27282
# leisure_hospitality_avg_monthly_pay                   1260        1296
# leisure_hospitality_aggr_value                    32593680    35357472
# other_services_all_employees                         12214       12380
# other_services_avg_monthly_pay                        2016        2144
# other_services_aggr_value                         24623424    26542720
# unclassified_all_employees                              13          13
# unclassified_avg_monthly_pay                          1732        1924
# unclassified_aggr_value                              22516       25012
# total_industries_aggr_value                     1045868792  1057442092
#
#                                                         67
# date                                               2010-05
# natural_resources_mining_all_employees                1137
# natural_resources_mining_avg_monthly_pay              2724
# natural_resources_mining_aggr_value                3097188
# construction_all_employees                           11891
# construction_avg_monthly_pay                          4356
# construction_aggr_value                           51797196
# manufacturing_all_employees                          33587
# manufacturing_avg_monthly_pay                         4564
# manufacturing_aggr_value                         153291068
# trade_transportation_utilities_all_employees         62962
# trade_transportation_utilities_avg_monthly_pay        2960
# trade_transportation_utilities_aggr_value        186367520
# information_all_employees                             6392
# information_avg_monthly_pay                           4872
# information_aggr_value                            31141824
# financial_activities_all_employees                   15728
# financial_activities_avg_monthly_pay                  4620
# financial_activities_aggr_value                   72663360
# professional_business_services_all_employees         35356
# professional_business_services_avg_monthly_pay        4360
# professional_business_services_aggr_value        154152160
# education_health_services_all_employees              89267
# education_health_services_avg_monthly_pay             3912
# education_health_services_aggr_value             349212504
# leisure_hospitality_all_employees                    28540
# leisure_hospitality_avg_monthly_pay                   1296
# leisure_hospitality_aggr_value                    36987840
# other_services_all_employees                         12476
# other_services_avg_monthly_pay                        2144
# other_services_aggr_value                         26748544
# unclassified_all_employees                              14
# unclassified_avg_monthly_pay                          1924
# unclassified_aggr_value                              26936
# total_industries_aggr_value                     1065486140

# %%
nhct.to_csv("./bls-api-data/" +str(city)+str(start)+'-'+str(end)+".csv")

# %% [markdown]
# ### New London, CT

# %%
city = "NewLondon"
start = "2010"
end = "2015"
code= "C3598"

# %%
nlct = bls_pull(registration_key=keys[0], start_year=start, end_year=end, area_code=code)

# %%
nlct.head().T
# Out:
#                                                        71         70  \
# date                                              2010-01    2010-02
# natural_resources_mining_all_employees                869        868
# natural_resources_mining_avg_monthly_pay             2312       2312
# natural_resources_mining_aggr_value               2009128    2006816
# construction_all_employees                           2734       2880
# construction_avg_monthly_pay                         4012       4012
# construction_aggr_value                          10968808   11554560
# manufacturing_all_employees                         14430      14288
# manufacturing_avg_monthly_pay                        6632       6632
# manufacturing_aggr_value                         95699760   94758016
# trade_transportation_utilities_all_employees        20914      20543
# trade_transportation_utilities_avg_monthly_pay       3412       3412
# trade_transportation_utilities_aggr_value        71358568   70092716
# information_all_employees                            1436       1400
# information_avg_monthly_pay                          3600       3600
# information_aggr_value                            5169600    5040000
# financial_activities_all_employees                   2796       2782
# financial_activities_avg_monthly_pay                 3948       3948
# financial_activities_aggr_value                  11038608   10983336
# professional_business_services_all_employees         8462       8655
# professional_business_services_avg_monthly_pay       6296       6296
# professional_business_services_aggr_value        53276752   54491880
# education_health_services_all_employees             18045      18180
# education_health_services_avg_monthly_pay            3112       3112
# education_health_services_aggr_value             56156040   56576160
# leisure_hospitality_all_employees                   11320      11286
# leisure_hospitality_avg_monthly_pay                  1384       1384
# leisure_hospitality_aggr_value                   15666880   15619824
# other_services_all_employees                         3199       3202
# other_services_avg_monthly_pay                       1872       1872
# other_services_aggr_value                         5988528    5994144
# unclassified_all_employees                              1          1
# unclassified_avg_monthly_pay                         1108       1108
# unclassified_aggr_value                              1108       1108
# total_industries_aggr_value                     327333780  327118560
#
#                                                        69         68  \
# date                                              2010-03    2010-04
# natural_resources_mining_all_employees                897       1230
# natural_resources_mining_avg_monthly_pay             2312       2392
# natural_resources_mining_aggr_value               2073864    2942160
# construction_all_employees                           2910       3450
# construction_avg_monthly_pay                         4012       4156
# construction_aggr_value                          11674920   14338200
# manufacturing_all_employees                         14280      14209
# manufacturing_avg_monthly_pay                        6632       6072
# manufacturing_aggr_value                         94704960   86277048
# trade_transportation_utilities_all_employees        20632      20672
# trade_transportation_utilities_avg_monthly_pay       3412       3160
# trade_transportation_utilities_aggr_value        70396384   65323520
# information_all_employees                            1393       1389
# information_avg_monthly_pay                          3600       3640
# information_aggr_value                            5014800    5055960
# financial_activities_all_employees                   2784       2795
# financial_activities_avg_monthly_pay                 3948       3872
# financial_activities_aggr_value                  10991232   10822240
# professional_business_services_all_employees         8620       8841
# professional_business_services_avg_monthly_pay       6296       5036
# professional_business_services_aggr_value        54271520   44523276
# education_health_services_all_employees             18270      18364
# education_health_services_avg_monthly_pay            3112       3352
# education_health_services_aggr_value             56856240   61556128
# leisure_hospitality_all_employees                   11595      12425
# leisure_hospitality_avg_monthly_pay                  1384       1444
# leisure_hospitality_aggr_value                   16047480   17941700
# other_services_all_employees                         3187       3257
# other_services_avg_monthly_pay                       1872       1968
# other_services_aggr_value                         5966064    6409776
# unclassified_all_employees                              1          2
# unclassified_avg_monthly_pay                         1108       3684
# unclassified_aggr_value                              1108       7368
# total_industries_aggr_value                     327998572  315197376
#
#                                                        67
# date                                              2010-05
# natural_resources_mining_all_employees               1255
# natural_resources_mining_avg_monthly_pay             2392
# natural_resources_mining_aggr_value               3001960
# construction_all_employees                           3255
# construction_avg_monthly_pay                         4156
# construction_aggr_value                          13527780
# manufacturing_all_employees                         14293
# manufacturing_avg_monthly_pay                        6072
# manufacturing_aggr_value                         86787096
# trade_transportation_utilities_all_employees        21364
# trade_transportation_utilities_avg_monthly_pay       3160
# trade_transportation_utilities_aggr_value        67510240
# information_all_employees                            1407
# information_avg_monthly_pay                          3640
# information_aggr_value                            5121480
# financial_activities_all_employees                   2811
# financial_activities_avg_monthly_pay                 3872
# financial_activities_aggr_value                  10884192
# professional_business_services_all_employees         8944
# professional_business_services_avg_monthly_pay       5036
# professional_business_services_aggr_value        45041984
# education_health_services_all_employees             18472
# education_health_services_avg_monthly_pay            3352
# education_health_services_aggr_value             61918144
# leisure_hospitality_all_employees                   13157
# leisure_hospitality_avg_monthly_pay                  1444
# leisure_hospitality_aggr_value                   18998708
# other_services_all_employees                         3342
# other_services_avg_monthly_pay                       1968
# other_services_aggr_value                         6577056
# unclassified_all_employees                              2
# unclassified_avg_monthly_pay                         3684
# unclassified_aggr_value                              7368
# total_industries_aggr_value                     319376008

# %%
nlct.to_csv("./bls-api-data/" +str(city)+str(start)+'-'+str(end)+".csv")

# %% [markdown]
# ### Boston, MA

# %%
city = "Boston"
start = "2010"
end = "2015"
code= "C1446"

# %%
boma = bls_pull(registration_key=keys[0], start_year=start, end_year=end, area_code=code)

# %%
boma.head().T
# Out:
#                                                          71           70  \
# date                                                2010-01      2010-02
# natural_resources_mining_all_employees                 3208         3146
# natural_resources_mining_avg_monthly_pay               3900         3900
# natural_resources_mining_aggr_value             1.25112e+07  1.22694e+07
# construction_all_employees                            68684        66513
# construction_avg_monthly_pay                           4776         4776
# construction_aggr_value                         3.28035e+08  3.17666e+08
# manufacturing_all_employees                          177327       176680
# manufacturing_avg_monthly_pay                          6100         6100
# manufacturing_aggr_value                        1.08169e+09  1.07775e+09
# trade_transportation_utilities_all_employees         377873       371769
# trade_transportation_utilities_avg_monthly_pay         3216         3216
# trade_transportation_utilities_aggr_value        1215239568   1195609104
# information_all_employees                             73128        72859
# information_avg_monthly_pay                            7576         7576
# information_aggr_value                            554017728    551979784
# financial_activities_all_employees                   174318       173703
# financial_activities_avg_monthly_pay                  10488        10488
# financial_activities_aggr_value                  1828247184   1821797064
# professional_business_services_all_employees         376261       376570
# professional_business_services_avg_monthly_pay         6372         6372
# professional_business_services_aggr_value        2397535092   2399504040
# education_health_services_all_employees              449574       454036
# education_health_services_avg_monthly_pay              3960         3960
# education_health_services_aggr_value             1780313040   1797982560
# leisure_hospitality_all_employees                    203108       202018
# leisure_hospitality_avg_monthly_pay                    1676         1676
# leisure_hospitality_aggr_value                    340409008    338582168
# other_services_all_employees                          91635        88859
# other_services_avg_monthly_pay                         2164         2164
# other_services_aggr_value                         198298140    192290876
# unclassified_all_employees                                4            6
# unclassified_avg_monthly_pay                           2240         2240
# unclassified_aggr_value                                8960        13440
# total_industries_aggr_value                     9.73631e+09  9.70544e+09
#
#                                                          69           68  \
# date                                                2010-03      2010-04
# natural_resources_mining_all_employees                 3310         4014
# natural_resources_mining_avg_monthly_pay               3900         3160
# natural_resources_mining_aggr_value              1.2909e+07  1.26842e+07
# construction_all_employees                            67780        73080
# construction_avg_monthly_pay                           4776         4776
# construction_aggr_value                         3.23717e+08   3.4903e+08
# manufacturing_all_employees                          176809       177217
# manufacturing_avg_monthly_pay                          6100         6144
# manufacturing_aggr_value                        1.07853e+09  1.08882e+09
# trade_transportation_utilities_all_employees         372095       375657
# trade_transportation_utilities_avg_monthly_pay         3216         3248
# trade_transportation_utilities_aggr_value        1196657520   1220133936
# information_all_employees                             72891        73059
# information_avg_monthly_pay                            7576         7060
# information_aggr_value                            552222216    515796540
# financial_activities_all_employees                   173374       173113
# financial_activities_avg_monthly_pay                  10488         6912
# financial_activities_aggr_value                  1818346512   1196557056
# professional_business_services_all_employees         378166       386512
# professional_business_services_avg_monthly_pay         6372         6144
# professional_business_services_aggr_value        2409673752   2374729728
# education_health_services_all_employees              455766       457261
# education_health_services_avg_monthly_pay              3960         4224
# education_health_services_aggr_value             1804833360   1931470464
# leisure_hospitality_all_employees                    204593       217881
# leisure_hospitality_avg_monthly_pay                    1676         1756
# leisure_hospitality_aggr_value                    342897868    382599036
# other_services_all_employees                          88023        89888
# other_services_avg_monthly_pay                         2164         2256
# other_services_aggr_value                         190481772    202787328
# unclassified_all_employees                                3            9
# unclassified_avg_monthly_pay                           2240         1368
# unclassified_aggr_value                                6720        12312
# total_industries_aggr_value                     9.73028e+09  9.27462e+09
#
#                                                          67
# date                                                2010-05
# natural_resources_mining_all_employees                 4326
# natural_resources_mining_avg_monthly_pay               3160
# natural_resources_mining_aggr_value             1.36702e+07
# construction_all_employees                            76475
# construction_avg_monthly_pay                           4776
# construction_aggr_value                         3.65245e+08
# manufacturing_all_employees                          178016
# manufacturing_avg_monthly_pay                          6144
# manufacturing_aggr_value                        1.09373e+09
# trade_transportation_utilities_all_employees         379349
# trade_transportation_utilities_avg_monthly_pay         3248
# trade_transportation_utilities_aggr_value        1232125552
# information_all_employees                             73215
# information_avg_monthly_pay                            7060
# information_aggr_value                            516897900
# financial_activities_all_employees                   173660
# financial_activities_avg_monthly_pay                   6912
# financial_activities_aggr_value                  1200337920
# professional_business_services_all_employees         387001
# professional_business_services_avg_monthly_pay         6144
# professional_business_services_aggr_value        2377734144
# education_health_services_all_employees              456547
# education_health_services_avg_monthly_pay              4224
# education_health_services_aggr_value             1928454528
# leisure_hospitality_all_employees                    226242
# leisure_hospitality_avg_monthly_pay                    1756
# leisure_hospitality_aggr_value                    397280952
# other_services_all_employees                          92044
# other_services_avg_monthly_pay                         2256
# other_services_aggr_value                         207651264
# unclassified_all_employees                               15
# unclassified_avg_monthly_pay                           1368
# unclassified_aggr_value                               20520
# total_industries_aggr_value                     9.33315e+09

# %%
boma.to_csv("./bls-api-data/" +str(city)+str(start)+'-'+str(end)+".csv")

# %% [markdown]
# ### Newport, RI

# %%
city = "Newport"
start = "2010"
end = "2015"
code= "44005"

# %%
npri = bls_pull(registration_key=keys[2], start_year=start, end_year=end, area_code=code)

# %%
npri.head().T
# Out:
#                                                       71        70        69  \
# date                                             2010-01   2010-02   2010-03
# natural_resources_mining_all_employees               NaN       NaN       NaN
# natural_resources_mining_avg_monthly_pay             NaN       NaN       NaN
# natural_resources_mining_aggr_value                  NaN       NaN       NaN
# construction_all_employees                           NaN       NaN       NaN
# construction_avg_monthly_pay                         NaN       NaN       NaN
# construction_aggr_value                              NaN       NaN       NaN
# manufacturing_all_employees                         2362      2363      2368
# manufacturing_avg_monthly_pay                       6144      6144      6144
# manufacturing_aggr_value                        14512128  14518272  14548992
# trade_transportation_utilities_all_employees        4945      4871      4909
# trade_transportation_utilities_avg_monthly_pay      2300      2300      2300
# trade_transportation_utilities_aggr_value       11373500  11203300  11290700
# information_all_employees                            605       604       605
# information_avg_monthly_pay                         4292      4292      4292
# information_aggr_value                           2596660   2592368   2596660
# financial_activities_all_employees                  1452      1454      1466
# financial_activities_avg_monthly_pay                3760      3760      3760
# financial_activities_aggr_value                  5459520   5467040   5512160
# professional_business_services_all_employees        4420      4419      4495
# professional_business_services_avg_monthly_pay      4076      4076      4076
# professional_business_services_aggr_value       18015920  18011844  18321620
# education_health_services_all_employees             5382      5437      5504
# education_health_services_avg_monthly_pay           2456      2456      2456
# education_health_services_aggr_value            13218192  13353272  13517824
# leisure_hospitality_all_employees                   5486      5604      5744
# leisure_hospitality_avg_monthly_pay                 1420      1420      1420
# leisure_hospitality_aggr_value                   7790120   7957680   8156480
# other_services_all_employees                        1496      1506      1535
# other_services_avg_monthly_pay                      1840      1840      1840
# other_services_aggr_value                        2752640   2771040   2824400
# unclassified_all_employees                           NaN       NaN       NaN
# unclassified_avg_monthly_pay                         NaN       NaN       NaN
# unclassified_aggr_value                              NaN       NaN       NaN
# total_industries_aggr_value                          NaN       NaN       NaN
#
#                                                          68           67
# date                                                2010-04      2010-05
# natural_resources_mining_all_employees                  233          263
# natural_resources_mining_avg_monthly_pay               1964         1964
# natural_resources_mining_aggr_value                  457612       516532
# construction_all_employees                             1444         1535
# construction_avg_monthly_pay                           3188         3188
# construction_aggr_value                         4.60347e+06  4.89358e+06
# manufacturing_all_employees                            2389         2404
# manufacturing_avg_monthly_pay                          5256         5256
# manufacturing_aggr_value                           12556584     12635424
# trade_transportation_utilities_all_employees           5129         5244
# trade_transportation_utilities_avg_monthly_pay         2312         2312
# trade_transportation_utilities_aggr_value          11858248     12124128
# information_all_employees                               605          604
# information_avg_monthly_pay                            4320         4320
# information_aggr_value                              2613600      2609280
# financial_activities_all_employees                     1522         1536
# financial_activities_avg_monthly_pay                   3396         3396
# financial_activities_aggr_value                     5168712      5216256
# professional_business_services_all_employees           4662         4703
# professional_business_services_avg_monthly_pay         4264         4264
# professional_business_services_aggr_value          19878768     20053592
# education_health_services_all_employees                5532         5432
# education_health_services_avg_monthly_pay              2676         2676
# education_health_services_aggr_value               14803632     14536032
# leisure_hospitality_all_employees                      6741         7818
# leisure_hospitality_avg_monthly_pay                    1480         1480
# leisure_hospitality_aggr_value                      9976680     11570640
# other_services_all_employees                           1569         1655
# other_services_avg_monthly_pay                         1924         1924
# other_services_aggr_value                           3018756      3184220
# unclassified_all_employees                              NaN          NaN
# unclassified_avg_monthly_pay                            NaN          NaN
# unclassified_aggr_value                                 NaN          NaN
# total_industries_aggr_value                             NaN          NaN

# %%
npri.to_csv("./bls-api-data/" +str(city)+str(start)+'-'+str(end)+".csv")

# %% [markdown]
# ### Providence, RI

# %%
city = "Providence"
start = "2010"
end = "2015"
code= "C3930"

# %%
prri = bls_pull(registration_key=keys[0], start_year=start, end_year=end, area_code=code)

# %%
prri.head().T
# Out:
#                                                          71           70  \
# date                                                2010-01      2010-02
# natural_resources_mining_all_employees                 1792         1712
# natural_resources_mining_avg_monthly_pay               3456         3456
# natural_resources_mining_aggr_value             6.19315e+06  5.91667e+06
# construction_all_employees                            19750        19075
# construction_avg_monthly_pay                           3820         3820
# construction_aggr_value                          7.5445e+07  7.28665e+07
# manufacturing_all_employees                           64629        64738
# manufacturing_avg_monthly_pay                          3864         3864
# manufacturing_aggr_value                        2.49726e+08  2.50148e+08
# trade_transportation_utilities_all_employees         118760       117259
# trade_transportation_utilities_avg_monthly_pay         2568         2568
# trade_transportation_utilities_aggr_value         304975680    301121112
# information_all_employees                             12902        12868
# information_avg_monthly_pay                            4568         4568
# information_aggr_value                             58936336     58781024
# financial_activities_all_employees                    34871        34885
# financial_activities_avg_monthly_pay                   5056         5056
# financial_activities_aggr_value                   176307776    176378560
# professional_business_services_all_employees          63291        63371
# professional_business_services_avg_monthly_pay         4420         4420
# professional_business_services_aggr_value         279746220    280099820
# education_health_services_all_employees              134205       134567
# education_health_services_avg_monthly_pay              2944         2944
# education_health_services_aggr_value              395099520    396165248
# leisure_hospitality_all_employees                     62963        63211
# leisure_hospitality_avg_monthly_pay                    1184         1184
# leisure_hospitality_aggr_value                     74548192     74841824
# other_services_all_employees                          27340        26930
# other_services_avg_monthly_pay                         1696         1696
# other_services_aggr_value                          46368640     45673280
# unclassified_all_employees                                4            0
# unclassified_avg_monthly_pay                           2996         2996
# unclassified_aggr_value                               11984            0
# total_industries_aggr_value                     1.66736e+09  1.66199e+09
#
#                                                          69           68  \
# date                                                2010-03      2010-04
# natural_resources_mining_all_employees                 2071         2731
# natural_resources_mining_avg_monthly_pay               3456         4932
# natural_resources_mining_aggr_value             7.15738e+06  1.34693e+07
# construction_all_employees                            19529        21942
# construction_avg_monthly_pay                           3820         3800
# construction_aggr_value                         7.46008e+07  8.33796e+07
# manufacturing_all_employees                           64673        64763
# manufacturing_avg_monthly_pay                          3864         3888
# manufacturing_aggr_value                        2.49896e+08  2.51799e+08
# trade_transportation_utilities_all_employees         117658       117447
# trade_transportation_utilities_avg_monthly_pay         2568         2668
# trade_transportation_utilities_aggr_value         302145744    313348596
# information_all_employees                             12784        12767
# information_avg_monthly_pay                            4568         4348
# information_aggr_value                             58397312     55510916
# financial_activities_all_employees                    35130        34721
# financial_activities_avg_monthly_pay                   5056         4400
# financial_activities_aggr_value                   177617280    152772400
# professional_business_services_all_employees          64293        67348
# professional_business_services_avg_monthly_pay         4420         3852
# professional_business_services_aggr_value         284175060    259424496
# education_health_services_all_employees              135447       135513
# education_health_services_avg_monthly_pay              2944         3200
# education_health_services_aggr_value              398755968    433641600
# leisure_hospitality_all_employees                     63725        67838
# leisure_hospitality_avg_monthly_pay                    1184         1244
# leisure_hospitality_aggr_value                     75450400     84390472
# other_services_all_employees                          26662        27152
# other_services_avg_monthly_pay                         1696         1804
# other_services_aggr_value                          45218752     48982208
# unclassified_all_employees                                0            0
# unclassified_avg_monthly_pay                           2996         3152
# unclassified_aggr_value                                   0            0
# total_industries_aggr_value                     1.67342e+09  1.69672e+09
#
#                                                          67
# date                                                2010-05
# natural_resources_mining_all_employees                 2801
# natural_resources_mining_avg_monthly_pay               4932
# natural_resources_mining_aggr_value             1.38145e+07
# construction_all_employees                            23322
# construction_avg_monthly_pay                           3800
# construction_aggr_value                         8.86236e+07
# manufacturing_all_employees                           65366
# manufacturing_avg_monthly_pay                          3888
# manufacturing_aggr_value                        2.54143e+08
# trade_transportation_utilities_all_employees         118436
# trade_transportation_utilities_avg_monthly_pay         2668
# trade_transportation_utilities_aggr_value         315987248
# information_all_employees                             12841
# information_avg_monthly_pay                            4348
# information_aggr_value                             55832668
# financial_activities_all_employees                    34824
# financial_activities_avg_monthly_pay                   4400
# financial_activities_aggr_value                   153225600
# professional_business_services_all_employees          67343
# professional_business_services_avg_monthly_pay         3852
# professional_business_services_aggr_value         259405236
# education_health_services_all_employees              135881
# education_health_services_avg_monthly_pay              3200
# education_health_services_aggr_value              434819200
# leisure_hospitality_all_employees                     71926
# leisure_hospitality_avg_monthly_pay                    1244
# leisure_hospitality_aggr_value                     89475944
# other_services_all_employees                          27890
# other_services_avg_monthly_pay                         1804
# other_services_aggr_value                          50313560
# unclassified_all_employees                                0
# unclassified_avg_monthly_pay                           3152
# unclassified_aggr_value                                   0
# total_industries_aggr_value                     1.71564e+09

# %%
prri.to_csv("./bls-api-data/" +str(city)+str(start)+'-'+str(end)+".csv")

# %% [markdown]
# ### Worcester County, MD

# %%
city = "WorcesterCounty"
start = "2010"
end = "2015"
code= "24047"

# %%
wcmd = bls_pull(registration_key=keys[0], start_year=start, end_year=end, area_code=code)

# %%
wcmd.head().T
# Out:
#                                                       71        70        69  \
# date                                             2010-01   2010-02   2010-03
# natural_resources_mining_all_employees                66        65        66
# natural_resources_mining_avg_monthly_pay            2032      2032      2032
# natural_resources_mining_aggr_value               134112    132080    134112
# construction_all_employees                           981       945      1002
# construction_avg_monthly_pay                        2432      2432      2432
# construction_aggr_value                          2385792   2298240   2436864
# manufacturing_all_employees                          627       641       662
# manufacturing_avg_monthly_pay                       2564      2564      2564
# manufacturing_aggr_value                         1607628   1643524   1697368
# trade_transportation_utilities_all_employees        3492      3373      3512
# trade_transportation_utilities_avg_monthly_pay      1836      1836      1836
# trade_transportation_utilities_aggr_value        6411312   6192828   6448032
# information_all_employees                            117       113       110
# information_avg_monthly_pay                         2528      2528      2528
# information_aggr_value                            295776    285664    278080
# financial_activities_all_employees                  1002       987      1012
# financial_activities_avg_monthly_pay                2496      2496      2496
# financial_activities_aggr_value                  2500992   2463552   2525952
# professional_business_services_all_employees         932       912       969
# professional_business_services_avg_monthly_pay      2512      2512      2512
# professional_business_services_aggr_value        2341184   2290944   2434128
# education_health_services_all_employees             2004      1998      2017
# education_health_services_avg_monthly_pay           2728      2728      2728
# education_health_services_aggr_value             5466912   5450544   5502376
# leisure_hospitality_all_employees                   4556      4474      5304
# leisure_hospitality_avg_monthly_pay                 1272      1272      1272
# leisure_hospitality_aggr_value                   5795232   5690928   6746688
# other_services_all_employees                         647       634       645
# other_services_avg_monthly_pay                      1716      1716      1716
# other_services_aggr_value                        1110252   1087944   1106820
# total_industries_aggr_value                     28049192  27536248  29310420
#
#                                                       68        67
# date                                             2010-04   2010-05
# natural_resources_mining_all_employees                66        74
# natural_resources_mining_avg_monthly_pay            1940      1940
# natural_resources_mining_aggr_value               128040    143560
# construction_all_employees                          1061      1120
# construction_avg_monthly_pay                        2536      2536
# construction_aggr_value                          2690696   2840320
# manufacturing_all_employees                          745       759
# manufacturing_avg_monthly_pay                       2572      2572
# manufacturing_aggr_value                         1916140   1952148
# trade_transportation_utilities_all_employees        3801      4069
# trade_transportation_utilities_avg_monthly_pay      1876      1876
# trade_transportation_utilities_aggr_value        7130676   7633444
# information_all_employees                            114       116
# information_avg_monthly_pay                         2588      2588
# information_aggr_value                            295032    300208
# financial_activities_all_employees                  1052      1107
# financial_activities_avg_monthly_pay                2284      2284
# financial_activities_aggr_value                  2402768   2528388
# professional_business_services_all_employees        1069      1124
# professional_business_services_avg_monthly_pay      2364      2364
# professional_business_services_aggr_value        2527116   2657136
# education_health_services_all_employees             2057      2175
# education_health_services_avg_monthly_pay           2712      2712
# education_health_services_aggr_value             5578584   5898600
# leisure_hospitality_all_employees                   7087      9082
# leisure_hospitality_avg_monthly_pay                 1256      1256
# leisure_hospitality_aggr_value                   8901272  11406992
# other_services_all_employees                         692       732
# other_services_avg_monthly_pay                      1776      1776
# other_services_aggr_value                        1228992   1300032
# total_industries_aggr_value                     32799316  36660828

# %%
wcmd.to_csv("./bls-api-data/" +str(city)+str(start)+'-'+str(end)+".csv")

# %% [markdown]
# ### Baltimore, MD

# %%
city = "Baltimore"
start = "2010"
end = "2015"
code= "C1258"

# %%
blmd = bls_pull(registration_key=keys[0], start_year=start, end_year=end, area_code=code)

# %%
blmd.head().T
# Out:
#                                                          71           70  \
# date                                                2010-01      2010-02
# natural_resources_mining_all_employees                 1599         1569
# natural_resources_mining_avg_monthly_pay               2540         2540
# natural_resources_mining_aggr_value             4.06146e+06  3.98526e+06
# construction_all_employees                            62816        59362
# construction_avg_monthly_pay                           4024         4024
# construction_aggr_value                         2.52772e+08  2.38873e+08
# manufacturing_all_employees                           62230        61172
# manufacturing_avg_monthly_pay                          5204         5204
# manufacturing_aggr_value                          323844920    318339088
# trade_transportation_utilities_all_employees         212316       206889
# trade_transportation_utilities_avg_monthly_pay         3080         3080
# trade_transportation_utilities_aggr_value         653933280    637218120
# information_all_employees                             20115        20083
# information_avg_monthly_pay                            4896         4896
# information_aggr_value                             98483040     98326368
# financial_activities_all_employees                    68591        68166
# financial_activities_avg_monthly_pay                   6084         6084
# financial_activities_aggr_value                   417307644    414721944
# professional_business_services_all_employees         165365       163168
# professional_business_services_avg_monthly_pay         4808         4808
# professional_business_services_aggr_value         795074920    784511744
# education_health_services_all_employees              221766       219478
# education_health_services_avg_monthly_pay              3412         3412
# education_health_services_aggr_value              756665592    748858936
# leisure_hospitality_all_employees                    104352       102061
# leisure_hospitality_avg_monthly_pay                    1436         1436
# leisure_hospitality_aggr_value                    149849472    146559596
# other_services_all_employees                          39568        38797
# other_services_avg_monthly_pay                         2384         2384
# other_services_aggr_value                          94330112     92492048
# unclassified_all_employees                                1            1
# unclassified_avg_monthly_pay                           1856         1856
# unclassified_aggr_value                                1856         1856
# total_industries_aggr_value                     3.54632e+09  3.48389e+09
#
#                                                          69           68  \
# date                                                2010-03      2010-04
# natural_resources_mining_all_employees                 1768         1971
# natural_resources_mining_avg_monthly_pay               2540         2636
# natural_resources_mining_aggr_value             4.49072e+06  5.19556e+06
# construction_all_employees                            62450        65476
# construction_avg_monthly_pay                           4024         4024
# construction_aggr_value                         2.51299e+08  2.63475e+08
# manufacturing_all_employees                           61571        61820
# manufacturing_avg_monthly_pay                          5204         4956
# manufacturing_aggr_value                          320415484    306379920
# trade_transportation_utilities_all_employees         211657       215266
# trade_transportation_utilities_avg_monthly_pay         3080         3000
# trade_transportation_utilities_aggr_value         651903560    645798000
# information_all_employees                             21196        21393
# information_avg_monthly_pay                            4896         4376
# information_aggr_value                            103775616     93615768
# financial_activities_all_employees                    68533        68315
# financial_activities_avg_monthly_pay                   6084         5172
# financial_activities_aggr_value                   416954772    353325180
# professional_business_services_all_employees         167768       170876
# professional_business_services_avg_monthly_pay         4808         4684
# professional_business_services_aggr_value         806628544    800383184
# education_health_services_all_employees              223438       224606
# education_health_services_avg_monthly_pay              3412         3632
# education_health_services_aggr_value              762370456    815768992
# leisure_hospitality_all_employees                    106877       111641
# leisure_hospitality_avg_monthly_pay                    1436         1512
# leisure_hospitality_aggr_value                    153475372    168801192
# other_services_all_employees                          40226        40768
# other_services_avg_monthly_pay                         2384         2508
# other_services_aggr_value                          95898784    102246144
# unclassified_all_employees                                6            1
# unclassified_avg_monthly_pay                           1856         1504
# unclassified_aggr_value                               11136         1504
# total_industries_aggr_value                     3.56722e+09  3.55499e+09
#
#                                                          67
# date                                                2010-05
# natural_resources_mining_all_employees                 2030
# natural_resources_mining_avg_monthly_pay               2636
# natural_resources_mining_aggr_value             5.35108e+06
# construction_all_employees                            66190
# construction_avg_monthly_pay                           4024
# construction_aggr_value                         2.66349e+08
# manufacturing_all_employees                           61813
# manufacturing_avg_monthly_pay                          4956
# manufacturing_aggr_value                          306345228
# trade_transportation_utilities_all_employees         216377
# trade_transportation_utilities_avg_monthly_pay         3000
# trade_transportation_utilities_aggr_value         649131000
# information_all_employees                             21149
# information_avg_monthly_pay                            4376
# information_aggr_value                             92548024
# financial_activities_all_employees                    68195
# financial_activities_avg_monthly_pay                   5172
# financial_activities_aggr_value                   352704540
# professional_business_services_all_employees         170968
# professional_business_services_avg_monthly_pay         4684
# professional_business_services_aggr_value         800814112
# education_health_services_all_employees              224586
# education_health_services_avg_monthly_pay              3632
# education_health_services_aggr_value              815696352
# leisure_hospitality_all_employees                    115798
# leisure_hospitality_avg_monthly_pay                    1512
# leisure_hospitality_aggr_value                    175086576
# other_services_all_employees                          41130
# other_services_avg_monthly_pay                         2508
# other_services_aggr_value                         103154040
# unclassified_all_employees                                1
# unclassified_avg_monthly_pay                           1504
# unclassified_aggr_value                                1504
# total_industries_aggr_value                     3.56718e+09

# %%
blmd.to_csv("./bls-api-data/" +str(city)+str(start)+'-'+str(end)+".csv")

# %% [markdown]
# ### Portland, ME

# %%
city = "Portland"
start = "2010"
end = "2015"
code= "C3886"

# %%
pome = bls_pull(registration_key=keys[0], start_year=start, end_year=end, area_code=code)

# %%
pome.head().T
# Out:
#                                                        71         70  \
# date                                              2010-01    2010-02
# natural_resources_mining_all_employees                NaN        NaN
# natural_resources_mining_avg_monthly_pay              NaN        NaN
# natural_resources_mining_aggr_value                   NaN        NaN
# construction_all_employees                           9256       9075
# construction_avg_monthly_pay                         3076       3076
# construction_aggr_value                          28471456   27914700
# manufacturing_all_employees                           NaN        NaN
# manufacturing_avg_monthly_pay                         NaN        NaN
# manufacturing_aggr_value                              NaN        NaN
# trade_transportation_utilities_all_employees        47573      46138
# trade_transportation_utilities_avg_monthly_pay       2376       2376
# trade_transportation_utilities_aggr_value       113033448  109623888
# information_all_employees                            4392       4404
# information_avg_monthly_pay                          4088       4088
# information_aggr_value                           17954496   18003552
# financial_activities_all_employees                  16361      16393
# financial_activities_avg_monthly_pay                 5136       5136
# financial_activities_aggr_value                  84030096   84194448
# professional_business_services_all_employees        26701      26655
# professional_business_services_avg_monthly_pay       3952       3952
# professional_business_services_aggr_value       105522352  105340560
# education_health_services_all_employees             45336      45365
# education_health_services_avg_monthly_pay            2876       2876
# education_health_services_aggr_value            130386336  130469740
# leisure_hospitality_all_employees                   22926      22898
# leisure_hospitality_avg_monthly_pay                  1236       1236
# leisure_hospitality_aggr_value                   28336536   28301928
# other_services_all_employees                         6876       6819
# other_services_avg_monthly_pay                       2004       2004
# other_services_aggr_value                        13779504   13665276
# unclassified_all_employees                              1          1
# unclassified_avg_monthly_pay                         1292       1292
# unclassified_aggr_value                              1292       1292
# total_industries_aggr_value                           NaN        NaN
#
#                                                        69         68  \
# date                                              2010-03    2010-04
# natural_resources_mining_all_employees                NaN        NaN
# natural_resources_mining_avg_monthly_pay              NaN        NaN
# natural_resources_mining_aggr_value                   NaN        NaN
# construction_all_employees                           9073       9853
# construction_avg_monthly_pay                         3076       3120
# construction_aggr_value                          27908548   30741360
# manufacturing_all_employees                           NaN        NaN
# manufacturing_avg_monthly_pay                         NaN        NaN
# manufacturing_aggr_value                              NaN        NaN
# trade_transportation_utilities_all_employees        46150      46329
# trade_transportation_utilities_avg_monthly_pay       2376       2400
# trade_transportation_utilities_aggr_value       109652400  111189600
# information_all_employees                            4421       4446
# information_avg_monthly_pay                          4088       3760
# information_aggr_value                           18073048   16716960
# financial_activities_all_employees                  16447      16508
# financial_activities_avg_monthly_pay                 5136       4132
# financial_activities_aggr_value                  84471792   68211056
# professional_business_services_all_employees        26665      27159
# professional_business_services_avg_monthly_pay       3952       3904
# professional_business_services_aggr_value       105380080  106028736
# education_health_services_all_employees             45398      45404
# education_health_services_avg_monthly_pay            2876       3052
# education_health_services_aggr_value            130564648  138573008
# leisure_hospitality_all_employees                   23277      26595
# leisure_hospitality_avg_monthly_pay                  1236       1228
# leisure_hospitality_aggr_value                   28770372   32658660
# other_services_all_employees                         6844       6898
# other_services_avg_monthly_pay                       2004       2096
# other_services_aggr_value                        13715376   14458208
# unclassified_all_employees                              1          0
# unclassified_avg_monthly_pay                         1292          0
# unclassified_aggr_value                              1292          0
# total_industries_aggr_value                           NaN        NaN
#
#                                                        67
# date                                              2010-05
# natural_resources_mining_all_employees                NaN
# natural_resources_mining_avg_monthly_pay              NaN
# natural_resources_mining_aggr_value                   NaN
# construction_all_employees                          10520
# construction_avg_monthly_pay                         3120
# construction_aggr_value                          32822400
# manufacturing_all_employees                           NaN
# manufacturing_avg_monthly_pay                         NaN
# manufacturing_aggr_value                              NaN
# trade_transportation_utilities_all_employees        47612
# trade_transportation_utilities_avg_monthly_pay       2400
# trade_transportation_utilities_aggr_value       114268800
# information_all_employees                            4516
# information_avg_monthly_pay                          3760
# information_aggr_value                           16980160
# financial_activities_all_employees                  16650
# financial_activities_avg_monthly_pay                 4132
# financial_activities_aggr_value                  68797800
# professional_business_services_all_employees        27479
# professional_business_services_avg_monthly_pay       3904
# professional_business_services_aggr_value       107278016
# education_health_services_all_employees             45449
# education_health_services_avg_monthly_pay            3052
# education_health_services_aggr_value            138710348
# leisure_hospitality_all_employees                   30290
# leisure_hospitality_avg_monthly_pay                  1228
# leisure_hospitality_aggr_value                   37196120
# other_services_all_employees                         7070
# other_services_avg_monthly_pay                       2096
# other_services_aggr_value                        14818720
# unclassified_all_employees                              0
# unclassified_avg_monthly_pay                            0
# unclassified_aggr_value                                 0
# total_industries_aggr_value                           NaN

# %%
pome.to_csv("./bls-api-data/" +str(city)+str(start)+'-'+str(end)+".csv")

# %% [markdown]
# ### Dukes County, MA

# %%
city = "DukesCounty"
start = "2010"
end = "2015"
code= "25007"

# %%
dcma = bls_pull(registration_key=keys[0], start_year=start, end_year=end, area_code=code)

# %%
dcma.head().T
# Out:
#                                                          71           70  \
# date                                                2010-01      2010-02
# natural_resources_mining_all_employees                   11           14
# natural_resources_mining_avg_monthly_pay               1780         1780
# natural_resources_mining_aggr_value                   19580        24920
# construction_all_employees                              605          588
# construction_avg_monthly_pay                           4028         4028
# construction_aggr_value                             2436940      2368464
# manufacturing_all_employees                              68           82
# manufacturing_avg_monthly_pay                          1864         1864
# manufacturing_aggr_value                             126752       152848
# trade_transportation_utilities_all_employees           1219         1180
# trade_transportation_utilities_avg_monthly_pay         2768         2768
# trade_transportation_utilities_aggr_value           3374192      3266240
# information_all_employees                               139          135
# information_avg_monthly_pay                            3292         3292
# information_aggr_value                               457588       444420
# financial_activities_all_employees                      314          307
# financial_activities_avg_monthly_pay                   4104         4104
# financial_activities_aggr_value                     1288656      1259928
# professional_business_services_all_employees            422          411
# professional_business_services_avg_monthly_pay         3600         3600
# professional_business_services_aggr_value           1519200      1479600
# education_health_services_all_employees                 740          739
# education_health_services_avg_monthly_pay              3824         3824
# education_health_services_aggr_value                2829760      2825936
# leisure_hospitality_all_employees                       711          714
# leisure_hospitality_avg_monthly_pay                    2416         2416
# leisure_hospitality_aggr_value                      1717776      1725024
# other_services_all_employees                            341          333
# other_services_avg_monthly_pay                         2484         2484
# other_services_aggr_value                            847044       827172
# total_industries_aggr_value                     1.46175e+07  1.43746e+07
#
#                                                          69       68       67
# date                                                2010-03  2010-04  2010-05
# natural_resources_mining_all_employees                   15      NaN      NaN
# natural_resources_mining_avg_monthly_pay               1780      NaN      NaN
# natural_resources_mining_aggr_value                   26700      NaN      NaN
# construction_all_employees                              617      648      679
# construction_avg_monthly_pay                           4028     4200     4200
# construction_aggr_value                             2485276  2721600  2851800
# manufacturing_all_employees                              82      NaN      NaN
# manufacturing_avg_monthly_pay                          1864      NaN      NaN
# manufacturing_aggr_value                             152848      NaN      NaN
# trade_transportation_utilities_all_employees           1197     1307     1490
# trade_transportation_utilities_avg_monthly_pay         2768     2596     2596
# trade_transportation_utilities_aggr_value           3313296  3392972  3868040
# information_all_employees                               137      133      137
# information_avg_monthly_pay                            3292     3568     3568
# information_aggr_value                               451004   474544   488816
# financial_activities_all_employees                      304      311      354
# financial_activities_avg_monthly_pay                   4104     3940     3940
# financial_activities_aggr_value                     1247616  1225340  1394760
# professional_business_services_all_employees            460      622      701
# professional_business_services_avg_monthly_pay         3600     3708     3708
# professional_business_services_aggr_value           1656000  2306376  2599308
# education_health_services_all_employees                 733      735      738
# education_health_services_avg_monthly_pay              3824     4140     4140
# education_health_services_aggr_value                2802992  3042900  3055320
# leisure_hospitality_all_employees                       711     1101     1524
# leisure_hospitality_avg_monthly_pay                    2416     1872     1872
# leisure_hospitality_aggr_value                      1717776  2061072  2852928
# other_services_all_employees                            336      358      377
# other_services_avg_monthly_pay                         2484     2508     2508
# other_services_aggr_value                            834624   897864   945516
# total_industries_aggr_value                     1.46881e+07      NaN      NaN

# %%
dcma.to_csv("./bls-api-data/" +str(city)+str(start)+'-'+str(end)+".csv")

# %% [markdown]
# ### Virginia Beach/Norfolk/Newport News, VA

# %%
city = "VirginiaBeach"
start = "2010"
end = "2015"
code= "C4726"

# %%
vbva = bls_pull(registration_key=keys[0], start_year=start, end_year=end, area_code=code)

# %%
vbva.head().T
# Out:
#                                                          71           70  \
# date                                                2010-01      2010-02
# natural_resources_mining_all_employees                  960          950
# natural_resources_mining_avg_monthly_pay               2476         2476
# natural_resources_mining_aggr_value             2.37696e+06   2.3522e+06
# construction_all_employees                              NaN          NaN
# construction_avg_monthly_pay                            NaN          NaN
# construction_aggr_value                                 NaN          NaN
# manufacturing_all_employees                           52104        52040
# manufacturing_avg_monthly_pay                          3932         3932
# manufacturing_aggr_value                        2.04873e+08  2.04621e+08
# trade_transportation_utilities_all_employees         123047       121615
# trade_transportation_utilities_avg_monthly_pay         2408         2408
# trade_transportation_utilities_aggr_value         296297176    292848920
# information_all_employees                             12494        12282
# information_avg_monthly_pay                            3792         3792
# information_aggr_value                          4.73772e+07  4.65733e+07
# financial_activities_all_employees                    34321        34225
# financial_activities_avg_monthly_pay                   3612         3612
# financial_activities_aggr_value                 1.23967e+08  1.23621e+08
# professional_business_services_all_employees          93599        93049
# professional_business_services_avg_monthly_pay         3640         3640
# professional_business_services_aggr_value         340700360    338698360
# education_health_services_all_employees               87743        87987
# education_health_services_avg_monthly_pay              2868         2868
# education_health_services_aggr_value            2.51647e+08  2.52347e+08
# leisure_hospitality_all_employees                     73704        74617
# leisure_hospitality_avg_monthly_pay                    1148         1148
# leisure_hospitality_aggr_value                  8.46122e+07  8.56603e+07
# other_services_all_employees                            NaN          NaN
# other_services_avg_monthly_pay                          NaN          NaN
# other_services_aggr_value                               NaN          NaN
# unclassified_all_employees                              NaN          NaN
# unclassified_avg_monthly_pay                            NaN          NaN
# unclassified_aggr_value                                 NaN          NaN
# total_industries_aggr_value                             NaN          NaN
#
#                                                          69           68  \
# date                                                2010-03      2010-04
# natural_resources_mining_all_employees                 1064         1135
# natural_resources_mining_avg_monthly_pay               2476         2444
# natural_resources_mining_aggr_value             2.63446e+06  2.77394e+06
# construction_all_employees                              NaN          NaN
# construction_avg_monthly_pay                            NaN          NaN
# construction_aggr_value                                 NaN          NaN
# manufacturing_all_employees                           52083        52045
# manufacturing_avg_monthly_pay                          3932         4280
# manufacturing_aggr_value                         2.0479e+08  2.22753e+08
# trade_transportation_utilities_all_employees         122536       123553
# trade_transportation_utilities_avg_monthly_pay         2408         2508
# trade_transportation_utilities_aggr_value         295066688    309870924
# information_all_employees                             12336        12225
# information_avg_monthly_pay                            3792         3628
# information_aggr_value                          4.67781e+07  4.43523e+07
# financial_activities_all_employees                    34231        34442
# financial_activities_avg_monthly_pay                   3612         3448
# financial_activities_aggr_value                 1.23642e+08  1.18756e+08
# professional_business_services_all_employees          93225        94187
# professional_business_services_avg_monthly_pay         3640         3732
# professional_business_services_aggr_value         339339000    351505884
# education_health_services_all_employees               88909          NaN
# education_health_services_avg_monthly_pay              2868          NaN
# education_health_services_aggr_value            2.54991e+08          NaN
# leisure_hospitality_all_employees                     77968        83330
# leisure_hospitality_avg_monthly_pay                    1148         1168
# leisure_hospitality_aggr_value                  8.95073e+07  9.73294e+07
# other_services_all_employees                            NaN        21881
# other_services_avg_monthly_pay                          NaN         1952
# other_services_aggr_value                               NaN  4.27117e+07
# unclassified_all_employees                              NaN          NaN
# unclassified_avg_monthly_pay                            NaN          NaN
# unclassified_aggr_value                                 NaN          NaN
# total_industries_aggr_value                             NaN          NaN
#
#                                                          67
# date                                                2010-05
# natural_resources_mining_all_employees                 1142
# natural_resources_mining_avg_monthly_pay               2444
# natural_resources_mining_aggr_value             2.79105e+06
# construction_all_employees                              NaN
# construction_avg_monthly_pay                            NaN
# construction_aggr_value                                 NaN
# manufacturing_all_employees                           52073
# manufacturing_avg_monthly_pay                          4280
# manufacturing_aggr_value                        2.22872e+08
# trade_transportation_utilities_all_employees         124940
# trade_transportation_utilities_avg_monthly_pay         2508
# trade_transportation_utilities_aggr_value         313349520
# information_all_employees                             12270
# information_avg_monthly_pay                            3628
# information_aggr_value                          4.45156e+07
# financial_activities_all_employees                    34440
# financial_activities_avg_monthly_pay                   3448
# financial_activities_aggr_value                 1.18749e+08
# professional_business_services_all_employees          92922
# professional_business_services_avg_monthly_pay         3732
# professional_business_services_aggr_value         346784904
# education_health_services_all_employees                 NaN
# education_health_services_avg_monthly_pay               NaN
# education_health_services_aggr_value                    NaN
# leisure_hospitality_all_employees                     86774
# leisure_hospitality_avg_monthly_pay                    1168
# leisure_hospitality_aggr_value                  1.01352e+08
# other_services_all_employees                          22136
# other_services_avg_monthly_pay                         1952
# other_services_aggr_value                       4.32095e+07
# unclassified_all_employees                              NaN
# unclassified_avg_monthly_pay                            NaN
# unclassified_aggr_value                                 NaN
# total_industries_aggr_value                             NaN

# %%
vbva.to_csv("./bls-api-data/" +str(city)+str(start)+'-'+str(end)+".csv")
