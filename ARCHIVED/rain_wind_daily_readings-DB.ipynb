# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt

# %%
atlantic_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/atlantic-city-nj.csv')
baltimore_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/baltimore-md.csv')
boston_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/boston-ma.csv')
bridgeport_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/bridgeport-ct.csv')
new_haven_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/new-haven-ct.csv')
new_london_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/new-london-ct.csv')
newport_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/newport-ri.csv')
portland_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/portland-me.csv')
ocean_city_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/ocean-city-md.csv')
providence_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/providence-ri.csv')
new_bedford_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/new-bedford-ma.csv')

# %%
def clean_prep(df):
    
    df = df.loc[:, ["DATE", "PRCP", "WSF2", "WSF5"]]
    
    df.rename(columns={'DATE': 'Date'}, inplace=True)
        
    df = df.set_index("Date")
    
    df.index = pd.to_datetime(df.index)
        
    return df

# %%
atlantic_prep = clean_prep(atlantic_prep)
baltimore_prep = clean_prep(baltimore_prep)
boston_prep = clean_prep(boston_prep)
bridgeport_prep = clean_prep(bridgeport_prep)
new_haven_prep = clean_prep(new_haven_prep)
new_london_prep = clean_prep(new_london_prep)
newport_prep = clean_prep(newport_prep)
portland_prep = clean_prep(portland_prep)
ocean_city_prep = clean_prep(ocean_city_prep)
providence_prep = clean_prep(providence_prep)
new_bedford_prep = clean_prep(new_bedford_prep)

# %%
atlantic_prep.to_csv("./weather-clean-data-original-time/atlantic_prep.csv")
boston_prep.to_csv("./weather-clean-data-original-time/boston_prep.csv")
bridgeport_prep.to_csv("./weather-clean-data-original-time/bridgeport_prep.csv")
new_haven_prep.to_csv("./weather-clean-data-original-time/new_haven_prep.csv")
new_london_prep.to_csv("./weather-clean-data-original-time/new_london_prep.csv")
newport_prep.to_csv("./weather-clean-data-original-time/newport_prep.csv")
baltimore_prep.to_csv("./weather-clean-data-original-time/baltimore_prep.csv")
ocean_city_prep.to_csv("./weather-clean-data-original-time/ocean_city_prep.csv")
portland_prep.to_csv("./weather-clean-data-original-time/portland_prep.csv")
providence_prep.to_csv("./weather-clean-data-original-time/providence_prep.csv")

# %%
atlantic_prep
# Out:
#             PRCP  WSF2  WSF5
# Date
# 2010-01-01  0.00   6.9  19.0
# 2010-01-02  0.00  14.1  34.9
# 2010-01-03  0.01  28.0  45.0
# 2010-01-04  0.00  10.1  25.1
# 2010-01-05  0.00   8.9  23.0
# 2010-01-06  0.00  10.1  25.1
# 2010-01-07  0.00   8.9  23.0
# 2010-01-08  0.06  11.0  27.1
# 2010-01-09  0.00  12.1  23.9
# 2010-01-10  0.00  10.1  25.1
# 2010-01-11  0.00   8.9  19.0
# 2010-01-12  0.00   8.9  23.0
# 2010-01-13  0.00  10.1  19.9
# 2010-01-14  0.00   8.9  17.0
# 2010-01-15  0.00  10.1  19.0
# 2010-01-16  0.00  12.1  19.9
# 2010-01-17  1.23  17.9  38.0
# 2010-01-18  0.24  10.1  23.9
# 2010-01-19  0.00   8.1  14.1
# 2010-01-20  0.00   8.1  17.9
# 2010-01-21  0.00   8.1  17.9
# 2010-01-22  0.00  14.1  25.9
# 2010-01-23  0.00  11.0  19.0
# 2010-01-24  0.00  17.0  32.0
# 2010-01-25  0.93  27.1  46.1
# 2010-01-26  0.06  14.1  25.9
# 2010-01-27  0.00  11.0  23.0
# 2010-01-28  0.00  16.1  33.1
# 2010-01-29  0.00  16.1  33.1
# 2010-01-30  0.30  11.0  25.1
# ...          ...   ...   ...
# 2015-12-02  0.07  17.0  28.0
# 2015-12-03  0.02  16.1  34.0
# 2015-12-04  0.00  10.1  19.0
# 2015-12-05  0.00   6.9  14.1
# 2015-12-06  0.00   8.9  14.1
# 2015-12-07  0.00  11.0  16.1
# 2015-12-08  0.00   8.9  18.1
# 2015-12-09  0.00  11.0  19.0
# 2015-12-10  0.00  10.1  16.1
# 2015-12-11  0.00  11.0  19.0
# 2015-12-12  0.00   8.9  14.1
# 2015-12-13  0.00   8.1  12.1
# 2015-12-14  0.14  19.9  33.1
# 2015-12-15  0.00  21.0  34.0
# 2015-12-16  0.00  10.1  17.0
# 2015-12-17  0.81  17.0  29.1
# 2015-12-18  0.00  12.1  23.9
# 2015-12-19  0.00  18.1  36.0
# 2015-12-20  0.00  12.1  21.9
# 2015-12-21  0.00  16.1  25.1
# 2015-12-22  0.56  16.1  29.1
# 2015-12-23  1.32  19.0  32.0
# 2015-12-24  0.16  21.0  34.0
# 2015-12-25  1.08  10.1  19.0
# 2015-12-26  0.00  17.0  25.1
# 2015-12-27  0.04  19.9  30.0
# 2015-12-28  0.03  28.0  38.9
# 2015-12-29  0.92  27.1  40.9
# 2015-12-30  0.08  11.0  19.0
# 2015-12-31  0.01  13.0  21.9
#
# [2191 rows x 3 columns]

# %%
plt.figure(figsize=(25, 15))
plt.plot(atlantic_prep["PRCP"], label='atlantic city')
plt.plot(boston_prep["PRCP"], label='boston')
plt.plot(bridgeport_prep["PRCP"], label='bridgeport')
plt.plot(new_haven_prep["PRCP"], label='new haven')
plt.plot(new_london_prep["PRCP"], label='new london')
plt.plot(newport_prep["PRCP"], label='newport')
plt.plot(baltimore_prep["PRCP"], label='baltimore')
plt.plot(ocean_city_prep["PRCP"], label='ocean city')
plt.plot(portland_prep["PRCP"], label='portland')
plt.plot(providence_prep["PRCP"], label='providence')
plt.xlim(pd.Timestamp('2012-10-26'), pd.Timestamp('2012-11-3'))
plt.legend();
# Out:
# /anaconda3/envs/dsi/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(25, 15))
plt.plot(atlantic_prep["WSF2"], label='atlantic city')
plt.plot(boston_prep["WSF2"], label='boston')
plt.plot(bridgeport_prep["WSF2"], label='bridgeport')
plt.plot(new_haven_prep["WSF2"], label='new haven')
plt.plot(new_london_prep["WSF2"], label='new london')
plt.plot(newport_prep["WSF2"], label='newport')
plt.plot(baltimore_prep["WSF2"], label='baltimore')
plt.plot(ocean_city_prep["WSF2"], label='ocean city')
plt.plot(portland_prep["WSF2"], label='portland')
plt.plot(providence_prep["WSF2"], label='providence')
plt.xlim(pd.Timestamp('2012-10-01'), pd.Timestamp('2012-11-30'))
plt.legend();

# %%
plt.figure(figsize=(25, 15))
plt.plot(atlantic_prep["WSF5"], label='atlantic city')
plt.plot(boston_prep["WSF5"], label='boston')
plt.plot(bridgeport_prep["WSF5"], label='bridgeport')
plt.plot(new_haven_prep["WSF5"], label='new haven')
plt.plot(new_london_prep["WSF5"], label='new london')
plt.plot(newport_prep["WSF5"], label='newport')
plt.plot(baltimore_prep["WSF5"], label='baltimore')
plt.plot(ocean_city_prep["WSF5"], label='ocean city')
plt.plot(portland_prep["WSF5"], label='portland')
plt.plot(providence_prep["WSF5"], label='providence')
plt.xlim(pd.Timestamp('2012-10-01'), pd.Timestamp('2012-11-30'))
plt.legend();
