# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt

# %%
atlantic_unemploy = pd.read_csv('./data/Atlantic_city_data/unemployment_nonseaonal.csv')
boston_unemploy = pd.read_csv('./data/Boston/unemployment_nonseasonal.csv')
bridgeport_unemploy = pd.read_csv('./data/bridgeport_data/unemployment_nonseasonal.csv')
new_haven_unemploy = pd.read_csv('./data/new_haven_data/unemployment_nonseasonal.csv')
new_london_unemploy = pd.read_csv('./data/new_london_data/unemployment_nonseasonal.csv')
newport_unemploy = pd.read_csv('./data/newport/unemployment_nonseasonal.csv')
baltimore_unemploy = pd.read_csv('./data/baltimore_data/unemployment_nonseasonal.csv')
ocean_city_unemploy = pd.read_csv('./data/ocean_city/unemployment_nonseasonal.csv')
portland_unemploy = pd.read_csv('./data/portland/unemployment_nonseasonal.csv')
providence_unemploy = pd.read_csv('./data/providence/unemployment_nonseasonal.csv')

# %%
plt.figure(figsize=(25,15))
plt.plot(atlantic_unemploy['DATE'],atlantic_unemploy['ATLA134URN'], label='Atlantic City')
# plt.xlim(pd.Timestamp('2010-01-01'), pd.Timestamp('2015-12-01'))

# %%
plt.figure(figsize=(25, 15))
plt.plot(atlantic_unemploy['ATLA134URN'], label='Atlantic City')
plt.plot(boston_unemploy['BOST625URN'], label='Boston')
plt.plot(bridgeport_unemploy['BRID909URN'], label='Bridgeport')
plt.plot(new_haven_unemploy['NEWH709URN'], label='New Haven')
plt.plot(new_london_unemploy['CTNEWL1URN'], label='New London')
plt.plot(newport_unemploy['RINEWP5URN'], label='Newport')
plt.plot(baltimore_unemploy['MDBALT5URN'], label='Baltimore')
plt.plot(ocean_city_unemploy['MDWORC7URN'], label='Ocean City')
plt.plot(portland_unemploy['PORT723URN'], label='Portland')
plt.plot(providence_unemploy['RIPROV7URN'], label='Providence')
# plt.xlabel('October 25, 2012 - November 3, 2012', fontsize=30)
# plt.ylabel('Maximum Daily Sustain 2 Minute Wind Speed (MPH)', fontsize=30)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# plt.xlim(pd.Timestamp('2010-01-01'), pd.Timestamp('2015-12-01'))
plt.legend(fontsize ='xx-large')
# plt.title(label='Maximum Daily Sustain 2 Minute Wind Speed', 
#           fontsize=40);
